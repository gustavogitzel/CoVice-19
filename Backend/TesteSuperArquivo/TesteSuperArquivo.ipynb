# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('WDICountry.csv')

# %%
df.columns
# Out:
# Index(['Country Code', 'Short Name', 'Table Name', 'Long Name', '2-alpha code',
#        'Currency Unit', 'Special Notes', 'Region', 'Income Group', 'WB-2 code',
#        'National accounts base year', 'National accounts reference year',
#        'SNA price valuation', 'Lending category', 'Other groups',
#        'System of National Accounts', 'Alternative conversion factor',
#        'PPP survey year', 'Balance of Payments Manual in use',
#        'External debt Reporting status', 'System of trade',
#        'Government Accounting concept', 'IMF data dissemination standard',
#        'Latest population census', 'Latest household survey',
#        'Source of most recent Income and expenditure data',
#        'Vital registration complete', 'Latest agricultural census',
#        'Latest industrial data', 'Latest trade data', 'Unnamed: 30'],
#       dtype='object')

# %%
df2 = pd.read_csv('WDICountry-Series.csv')

# %%
df2.head()
# Out:
#   CountryCode      SeriesCode  \
# 0         ABW     ST.INT.ARVL
# 1         ABW  ST.INT.TVLX.CD
# 2         ABW  ST.INT.TRNR.CD
# 3         ABW  ST.INT.TRNX.CD
# 4         ABW  ST.INT.TVLR.CD
#
#                                          DESCRIPTION  Unnamed: 3
# 0  Arrivals of non-resident tourists at national ...         NaN
# 1  Compiled from data reported in the Internation...         NaN
# 2  Compiled from data reported in the Internation...         NaN
# 3  Compiled from data reported in the Internation...         NaN
# 4  Compiled from data reported in the Internation...         NaN

# %%
df3 = pd.read_csv('WDIFootNote.csv')
df3.columns
# Out:
# Index(['CountryCode', 'SeriesCode', 'Year', 'DESCRIPTION', 'Unnamed: 4'], dtype='object')

# %%
df3 = pd.read_csv('WDISeries.csv')
df3.head()
# Out:
#          Series Code                                 Topic  \
# 0     AG.AGR.TRAC.NO  Environment: Agricultural production
# 1  AG.CON.FERT.PT.ZS  Environment: Agricultural production
# 2     AG.CON.FERT.ZS  Environment: Agricultural production
# 3     AG.LND.AGRI.K2                 Environment: Land use
# 4     AG.LND.AGRI.ZS                 Environment: Land use
#
#                                       Indicator Name Short definition  \
# 0                   Agricultural machinery, tractors              NaN
# 1  Fertilizer consumption (% of fertilizer produc...              NaN
# 2  Fertilizer consumption (kilograms per hectare ...              NaN
# 3                         Agricultural land (sq. km)              NaN
# 4                 Agricultural land (% of land area)              NaN
#
#                                      Long definition Unit of measure  \
# 0  Agricultural machinery refers to the number of...             NaN
# ...

# %%
df2 = pd.read_csv('WDISeries-Time.csv')
df2.columns
# Out:
# Index(['SeriesCode', 'Year', 'DESCRIPTION', 'Unnamed: 3'], dtype='object')
